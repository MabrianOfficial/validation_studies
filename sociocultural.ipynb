# %% [markdown]
# # Sociocultural evaluation

# %% [markdown]
# General imports:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style("darkgrid")
import matplotlib.pyplot as plt
import random
# %matplotlib inline

# %% [markdown]
# ### Known Languages (form & content):
# Source: `./files/socio_known_languages.xlsx`

# %%
df1 = pd.DataFrame([[68,80],[42,81],[29,74],[49,84],[49,68],[38,79]],columns=['score','score_naive'],
                  index=['machine-guiem','machine-yoli','machine-supriya','guiem-yoli','yoli-supriya','supriya-guiem'])
df1
# Out:
#                  score  score_naive
# machine-guiem       68           80
# machine-yoli        42           81
# machine-supriya     29           74
# guiem-yoli          49           84
# yoli-supriya        49           68
# supriya-guiem       38           79

# %%
df1.plot(kind='bar',figsize=(10, 7),ylim=(0,100))
print 'Mean:',df1.score.mean()
print 'Mean machine:',df1.head(3).score.mean()
print 'Mean human:',df1.tail(3).score.mean()
# Out:
# Mean: 45.8333333333
# Mean machine: 46.3333333333
# Mean human: 45.3333333333

# %% [markdown]
# ### All Languages (form):
# Source: ./files/socio_all_languages.xlsx

# %%
df2 = pd.DataFrame([[54,66],[29,73],[32,74],[25,73],[44,63],[30,82]],columns=['score','score_naive'],
                  index=['machine-guiem','machine-yoli','machine-supriya','guiem-yoli','yoli-supriya','supriya-guiem'])
df2
# Out:
#                  score  score_naive
# machine-guiem       54           66
# machine-yoli        29           73
# machine-supriya     32           74
# guiem-yoli          25           73
# yoli-supriya        44           63
# supriya-guiem       30           82

# %%
df2.plot(kind='bar',figsize=(10, 7),ylim=(0,100))
print 'Mean:',df2.score.mean()
print 'Mean machine:',df2.head(3).score.mean()
print 'Mean human:',df2.tail(3).score.mean()
# Out:
# Mean: 35.6666666667
# Mean machine: 38.3333333333
# Mean human: 33.0

# %% [markdown]
# ### Bonus

# %% [markdown]
# Sources: ./files/val_socio_bonus_guiem.xlsx, ./files/val_socio_bonus_xec.xlsx, ./files/val_socio_bonus_supri_done.xlsx

# %%
machine = np.array(['high', 'high', 'high', 'high', 'low', 'high', 'medium', 'high', 'medium', 'medium', 'low', 'medium', 'medium', 'medium', 'medium', 'medium', 'medium', 'high', 'medium', 'high', 'medium', 'high', 'medium', 'low', 'high', 'high', 'high', 'high', 'high', 'medium', 'high', 'high', 'high', 'high', 'medium', 'medium', 'medium', 'medium', 'medium', 'high', 'high', 'low', 'high', 'high', 'medium', 'low', 'high', 'high', 'high', 'low', 'high', 'high', 'low', 'low', 'low', 'low', 'high', 'low', 'low', 'low', 'low', 'low', 'low', 'medium', 'high', 'medium', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'medium', 'low', 'high', 'low', 'low', 'low', 'medium', 'low', 'low', 'high', 'high', 'medium', 'medium', 'medium', 'medium', 'high', 'medium', 'low', 'low', 'high', 'medium', 'medium', 'medium', 'medium', 'medium'])
guiem = np.array(['high', 'high', 'medium', 'medium', 'low', 'high', 'low', 'high', 'medium', 'low', 'low', 'low', 'low', 'medium', 'low', 'low', 'high', 'medium', 'low', 'high', 'high', 'low', 'low', 'low', 'high', 'high', 'medium', 'low', 'medium', 'high', 'low', 'medium', 'high', 'medium', 'low', 'low', 'low', 'low', 'low', 'low', 'medium', 'low', 'low', 'low', 'medium', 'low', 'medium', 'medium', 'high', 'low', 'high', 'low', 'low', 'low', 'low', 'low', 'high', 'low', 'medium', 'low', 'low', 'low', 'low', 'medium', 'high', 'low', 'low', 'low', 'low', 'low', 'medium', 'medium', 'low', 'low', 'medium', 'high', 'low', 'high', 'low', 'low', 'low', 'medium', 'low', 'low', 'high', 'high', 'medium', 'high', 'high', 'low', 'high', 'medium', 'low', 'low', 'high', 'medium', 'medium', 'high', 'low', 'low'])
yoli = np.array(['high', 'medium', 'medium', 'medium', 'medium', 'high', 'medium', 'medium', 'medium', "no entenc s'idioma", "no entenc s'idioma", 'low', 'high', 'medium', 'medium', 'low', 'medium', 'medium', 'medium', 'medium', 'medium', "no entenc s'idioma", 'medium', 'medium', 'medium', 'medium', 'high', 'medium', 'medium', 'high', "no entenc s'idioma", 'medium', 'high', 'medium', 'no hi ha res', 'medium', 'low', 'low', 'medium', 'medium', 'medium', 'medium', 'medium', 'medium', 'medium', 'medium', 'medium', 'medium', 'high', 'medium', 'medium', 'medium', 'medium', 'medium', 'high', 'low', 'medium', 'medium', 'medium', 'medium', 'medium', 'medium', 'medium', 'medium', 'high', 'low', 'medium', 'medium', 'low', 'no hi ha res', 'low', 'medium', 'medium', 'medium', 'medium', 'medium', 'medium', 'high', 'medium', 'medium', 'low', 'no hi ha res', 'low', 'low', 'high', 'low', 'high', 'medium', 'medium', 'medium', 'medium', 'medium', 'medium', 'medium', 'medium', 'medium', 'low', 'medium', 'low', 'medium'])
supri = np.array(['high', 'medium', 'medium', 'high', 'low', 'medium', 'medium', 'high', 'medium', 'high', 'medium', 'high', 'medium', 'high', 'low', 'low', 'high', 'high', 'medium', 'medium', 'high', 'medium', 'low', 'high', 'high', 'high', 'high', 'low', 'high', 'medium', 'medium', 'high', 'high', 'medium', 'high', 'high', 'medium', 'medium', 'high', 'low', 'medium', 'low', 'low', 'low', 'high', 'low', 'low', 'low', 'medium', 'low', 'high', 'low', 'low', 'low', 'low', 'low', 'high', 'medium', 'high', 'low', 'low', 'low', 'low', 'low', 'high', 'medium', 'low', 'low', 'medium', 'medium', 'medium', 'medium', 'medium', 'medium', 'medium', 'medium', 'low', 'medium', 'medium', 'medium', 'low', 'medium', 'low', 'medium', 'high', 'low', 'medium', 'low', 'medium', 'low', 'high', 'medium', 'low', 'low', 'high', 'high', 'low', 'medium', 'medium', 'medium'])

# %%
guiem_machine = np.count_nonzero(machine == guiem)
yoli_machine = np.count_nonzero(machine == yoli)
supri_machine = np.count_nonzero(machine == supri)
guiem_yoli = np.count_nonzero(yoli == guiem)
yoli_supri = np.count_nonzero(yoli == supri)
guiem_supri = np.count_nonzero(guiem == supri)
df3 = pd.DataFrame([[guiem_machine],[yoli_machine],[supri_machine],[guiem_yoli],[yoli_supri],[guiem_supri]],columns=['score'],
                  index=['machine-guiem','machine-yoli','machine-supriya','guiem-yoli','yoli-supriya','supriya-guiem'])
df3
# Out:
#                  score
# machine-guiem       55
# machine-yoli        34
# machine-supriya     51
# guiem-yoli          37
# yoli-supriya        31
# supriya-guiem       51

# %%
df3.plot(kind='bar',figsize=(10, 7),ylim=(0,100))
print 'Mean:',df3.score.mean()
print 'Mean machine:',df3.head(3).score.mean()
print 'Mean human:',df3.tail(3).score.mean()
# Out:
# Mean: 43.1666666667
# Mean machine: 46.6666666667
# Mean human: 39.6666666667

# %% [markdown]
# ### Final remarks

# %% [markdown]
# Total coincidence:

# %%
all_known = df1.score.mean()
all_all = df2.score.mean()
all_bonus = df3.score.mean()
print 'Mean known languages:',all_known
print 'Mean all languages:',all_all
print 'Mean bonus:',all_bonus
# Out:
# Mean known languages: 45.8333333333
# Mean all languages: 35.6666666667
# Mean bonus: 43.1666666667

# %% [markdown]
# Machine human coincidence:

# %%
machine_human_known = df1.head(3).score.mean()
machine_human_all = df2.head(3).score.mean()
machine_human_bonus = df3.head(3).score.mean()
print 'Mean machine known languages:', machine_human_known
print 'Mean machine all languages:', machine_human_all
print 'Mean machine bonus:', machine_human_bonus
# Out:
# Mean machine known languages: 46.3333333333
# Mean machine all languages: 38.3333333333
# Mean machine bonus: 46.6666666667

# %% [markdown]
# Human human coincidence:

# %%
human_human_known = df1.tail(3).score.mean()
human_human_all = df2.tail(3).score.mean()
human_human_bonus = df3.tail(3).score.mean()
print 'Mean human known languages:', human_human_known
print 'Mean human all languages:', human_human_all
print 'Mean human bonus:', human_human_bonus
# Out:
# Mean human known languages: 45.3333333333
# Mean human all languages: 33.0
# Mean human bonus: 39.6666666667

# %% [markdown]
# Machine human coincidence (NO Guiem):

# %%
machine_human_all_aux = df1[1:3].score.mean()
machine_human_known_aux = df2[1:3].score.mean()
machine_human_bonus_aux = df3[1:3].score.mean()
print 'Mean machine known languages', machine_human_all_aux
print 'Mean machine all languages', machine_human_known_aux
print 'Mean machine bonus', machine_human_bonus_aux
# Out:
# Mean machine known languages 35.5
# Mean machine all languages 30.5
# Mean machine bonus 42.5

# %% [markdown]
# Human human coincidence (NO Guiem):

# %%
human_human_all_aux = df1[4:5].score.mean()
human_human_known_aux = df2[4:5].score.mean()
human_human_bonus_aux = df3[4:5].score.mean()
print 'Mean machine known languages', human_human_all_aux
print 'Mean machine all languages', human_human_known_aux
print 'Mean machine bonus', human_human_bonus_aux
# Out:
# Mean machine known languages 49.0
# Mean machine all languages 44.0
# Mean machine bonus 31.0

# %%
df_summary = pd.DataFrame([[all_known,all_all],[machine_human_known,machine_human_all],
                           [human_human_known,human_human_all],[machine_human_all_aux,machine_human_known_aux],
                           [human_human_all_aux,human_human_known_aux]],
                           columns=['score known','score all'],index=['total','machine-human','human-human',
                                                                      'm-h-no_guiem','h-h-no_guiem'])
df_summary
summary_plt = df_summary.plot(kind='bar',figsize=(10, 7),ylim=(0,100),color=['#CC99FF','#9999FF'])
for p in summary_plt.patches:
    summary_plt.annotate(str(round(p.get_height(),2)), (p.get_x() * 1.005, p.get_height() * 1.02))

# %%
df_summary = pd.DataFrame([[all_known,all_all,all_bonus],[machine_human_known,machine_human_all,machine_human_bonus],
                           [human_human_known,human_human_all,human_human_bonus],[machine_human_all_aux,machine_human_known_aux,machine_human_bonus_aux],
                           [human_human_all_aux,human_human_known_aux,human_human_bonus_aux]],
                           columns=['score known','score all','score bonus'],index=['total','machine-human','human-human',
                                                                      'm-h-no_guiem','h-h-no_guiem'])
df_summary
summary_plt = df_summary.plot(kind='bar',figsize=(10, 7),ylim=(0,100),color=['#CC99FF','#9999FF','#CCFFE5'])
for p in summary_plt.patches:
    summary_plt.annotate(str(round(p.get_height(),2)), (p.get_x() * 1.005, p.get_height() * 1.02))

# %% [markdown]
# Random test (with all known languages):

# %%
machine_answers = ['low', 'low', 'low', 'low', 'low', 'medium', 'low', 'low', 'low', 'low', 'low', 'low', 'medium', 'low', 'low', 'medium', 'low', 'medium', 'high', 'low', 'low', 'medium', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'high', 'medium', 'low', 'low', 'low', 'high', 'high', 'low', 'medium', 'medium', 'low', 'medium', 'low', 'low', 'high', 'low', 'high', 'low', 'low', 'low', 'low', 'low', 'low', 'high', 'low', 'low', 'medium', 'medium', 'high', 'low', 'high', 'high', 'low', 'high', 'high', 'medium', 'low', 'high', 'low', 'low', 'high', 'high', 'medium', 'high', 'medium', 'low', 'high', 'low', 'low', 'low', 'low', 'low', 'low', 'medium', 'low', 'medium', 'high', 'low', 'high', 'high', 'low', 'medium', 'medium', 'low', 'high', 'medium', 'low', 'low']
machine_answers = np.array([0 if x=='low' else 1 if x=='medium' else 2 for x in machine_answers])
num_tests = 100
res = []
for i in range(0,num_tests):
    rand_answers = np.array([random.randint(0,2) for i in range(0,len(machine_answers))])
    res.append(np.count_nonzero(machine_answers == rand_answers))
plt.figure(figsize=(10, 7))
plt.plot(res)
print 'Max:', max(res)
print 'Min:', min(res)
print 'Mean:',np.array(res).mean()
# Out:
# Max: 51
# Min: 20
# Mean: 33.21
